# %% [markdown]
# # STACK

# %% [markdown]
# A STACK is a linear data structure.
# it follows/perform operations in the following order:
# I) LIFO:- last in first out
# II)FILO:- first in last out

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # REAL LIFE EXAMPLE :-
#     Plates stacked over one another.

# %% [raw]
# operations in satck:
#     i) Push: Adds an item in the stack. If the stack is full, then it is said to be an Overflow condition.
#
#    ii) Pop: Removes an item from the stack. The items are popped in the reversed order in which they are pushed. If the stack               is empty, then it is said to be an Underflow condition.
#
#   iii) Peek or Top: Returns top element of stack.
#
#    iv) isEmpty: Returns true if stack is empty, else false.

# %% [markdown]
# # Push

# %%
#initially top=-1
def push(x):
    global top
    if top == MAX-2:
        print("STACK OVERFLOW")
    else:
        top = top+1
        l[top]=x
    return l

# %% [markdown]
# # pop

# %%
def pop():
    global top
    if top == -1:
        print("STACK UNDERFLOW")
    else:
        temp=l[top]
        l[top]="NULL"
        top=top-1
        print(temp)

# %% [markdown]
# # top()

# %%
def top():
    global top
    return l[top]

# %% [markdown]
# # isempty()

# %%
def isempty():
    global top
    if top==-1:
        return True
    else:
        return False

# %%
MAX=6
l=(MAX-1)*["NULL"]
print(l)
top = -1
def push(x):
    global top
    if top == MAX-2:
        print("STACK OVERFLOW")
    else:
        top = top+1
        l[top]=x
    return l
def pop():
    global top
    if top == -1:
        print("STACK UNDERFLOW")
    else:
        temp=l[top]
        l[top]="NULL"
        top=top-1
        print(temp)
def top():
    global top
    return l[top]
def isempty():
    global top
    if top==-1:
        return True
    else:
        return False
# Out:
# ['NILL', 'NILL', 'NILL', 'NILL', 'NILL']
